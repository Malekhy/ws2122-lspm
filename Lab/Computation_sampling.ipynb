# %%
import os
import pandas as pd
import pm4py
from pm4py.algo.filtering.log.cases import case_filter
from pm4py.algo.filtering.pandas.timestamp import timestamp_filter
from pm4py.algo.filtering.log.start_activities import start_activities_filter
from pm4py.algo.filtering.log.end_activities import end_activities_filter
from pm4py.algo.filtering.log.variants import variants_filter
from pm4py.objects.log.util import dataframe_utils
from pm4py.objects.conversion.log import converter as log_converter
from pm4py.util import constants

# %%
#Import event log

log_csv = pd.read_csv('../eventlogs/ItalianHelpdeskFinal.csv', sep=',')
log_csv = dataframe_utils.convert_timestamp_columns_in_df(log_csv)
param_keys={constants.PARAMETER_CONSTANT_CASEID_KEY: 'Case ID', 
    constants.PARAMETER_CONSTANT_ACTIVITY_KEY: 'Activity', 
            constants.PARAMETER_CONSTANT_TIMESTAMP_KEY: "Complete Timestamp"
           }
log_csv
# Out:
#          Case ID               Activity org:resource  \
# 0         Case 1     Assign seriousness      Value 1
# 1         Case 1  Take in charge ticket      Value 1
# 2         Case 1  Take in charge ticket      Value 2
# 3         Case 1         Resolve ticket      Value 1
# 4         Case 1                 Closed      Value 3
# ...          ...                    ...          ...
# 21337  Case 4579                 Closed      Value 5
# 21338  Case 4580  Take in charge ticket      Value 6
# 21339  Case 4580                   Wait      Value 6
# 21340  Case 4580         Resolve ticket      Value 6
# 21341  Case 4580                 Closed      Value 5
#
#              Complete Timestamp seriousness  customer  product seriousness_2  \
# 0     2012-10-09 14:50:17+00:00     Value 1   Value 1  Value 1       Value 1
# 1     2012-10-09 14:51:01+00:00     Value 1   Value 1  Value 1       Value 1
# 2     2012-10-12 15:02:56+00:00     Value 1   Value 1  Value 1       Value 1
# 3     2012-10-25 11:54:26+00:00     Value 1   Value 1  Value 1       Value 1
# 4     2012-11-09 12:54:39+00:00     Value 1   Value 1  Value 1       Value 1
# ...                         ...         ...       ...      ...           ...
# 21337 2010-09-02 10:11:00+00:00     Value 1  Value 71  Value 3       Value 1
# 21338 2012-01-03 09:33:43+00:00     Value 1  Value 92  Value 3       Value 2
# 21339 2012-01-10 15:30:11+00:00     Value 1  Value 92  Value 3       Value 2
# 21340 2012-01-10 17:07:40+00:00     Value 1  Value 92  Value 3       Value 2
# 21341 2012-02-08 17:00:34+00:00     Value 1  Value 92  Value 3       Value 2
#
#       service_level service_type workgroup
# 0           Value 1      Value 1   Value 1
# 1           Value 1      Value 1   Value 1
# 2           Value 2      Value 1   Value 1
# 3           Value 2      Value 1   Value 1
# 4           Value 2      Value 1   Value 1
# ...             ...          ...       ...
# 21337       Value 3      Value 1   Value 1
# 21338       Value 2      Value 2   Value 1
# 21339       Value 2      Value 2   Value 1
# 21340       Value 2      Value 2   Value 1
# 21341       Value 2      Value 2   Value 1
#
# [21342 rows x 11 columns]

# %%
#Convert to dataframe

event_log = log_converter.apply(log_csv,parameters=param_keys)

# %% [markdown]
# ## 1-Traversing the event log:

# %%
#Insights to Variants

from pm4py.statistics.traces.pandas import case_statistics
variants = case_statistics.get_variants_df(log_csv,
                                          parameters={constants.PARAMETER_CONSTANT_CASEID_KEY: "Case ID",
                                                      constants.PARAMETER_CONSTANT_ACTIVITY_KEY: "Activity"})
variants.describe(include='all')

stats = variants.describe(include='all')
print (stats)
# Out:
#                                                   variant
# count                                                4579
# unique                                                226
# top     Assign seriousness,Take in charge ticket,Resol...
# freq                                                 2366

# %%
#Check cases

from pandas import DataFrame
df = DataFrame(log_csv, columns= ['Case ID', 'Activity','Complete Timestamp'])
count1 = df['Case ID'].count()
print('count cases: ' + str(count1))
# Out:
# count cases: 21342

# %%
#Group traces to each variant and order variants according to frequency of traces in variant

from pm4py.statistics.traces.pandas import case_statistics
variants_count = case_statistics.get_variant_statistics(log_csv,
                                          parameters={constants.PARAMETER_CONSTANT_CASEID_KEY: "Case ID",
                                                      constants.PARAMETER_CONSTANT_ACTIVITY_KEY: "Activity",
                                                      constants.PARAMETER_CONSTANT_TIMESTAMP_KEY: "Complete Timestamp"})
variants_count = sorted(variants_count, key=lambda x: x['Case ID'], reverse=True)
variants_count
# Out:
# [{'variant': 'Assign seriousness,Take in charge ticket,Resolve ticket,Closed',
#   'Case ID': 2366},
#  {'variant': 'Assign seriousness,Take in charge ticket,Wait,Resolve ticket,Closed',
#   'Case ID': 552},
#  {'variant': 'Assign seriousness,Take in charge ticket,Wait,Take in charge ticket,Resolve ticket,Closed',
#   'Case ID': 228},
#  {'variant': 'Assign seriousness,Assign seriousness,Take in charge ticket,Resolve ticket,Closed',
#   'Case ID': 213},
#  {'variant': 'Assign seriousness,Resolve ticket,Closed', 'Case ID': 164},
#  {'variant': 'Assign seriousness,Take in charge ticket,Resolve ticket,Resolve ticket,Closed',
#   'Case ID': 109},
#  {'variant': 'Insert ticket,Assign seriousness,Take in charge ticket,Resolve ticket,Closed',
#   'Case ID': 69},
#  {'variant': 'Assign seriousness,Resolve ticket,Resolve ticket,Closed',
#   'Case ID': 62},
#  {'variant': 'Assign seriousness,Take in charge ticket,Resolve ticket,Take in charge ticket,Resolve ticket,Closed',
#   'Case ID': 48},
#  {'variant': 'Assign seriousness,Take in charge ticket,Require upgrade,Resolve ticket,Closed',
#   'Case ID': 40},
#  {'variant': 'Take in charge ticket,Resolve ticket,Closed', 'Case ID': 37},
#  {'variant': 'Assign seriousness,Take in charge ticket,Take in charge ticket,Resolve ticket,Closed',
#   'Case ID': 36},
#  {'variant': 'Assign seriousness,Assign seriousness,Take in charge ticket,Wait,Take in charge ticket,Resolve ticket,Closed',
#   'Case ID': 35},
#  {'variant': 'Assign seriousness,Take in charge ticket,Wait,Wait,Resolve ticket,Closed',
#   'Case ID': 28},
#  {'variant': 'Assign seriousness,Take in charge ticket,Wait,Take in charge ticket,Wait,Resolve ticket,Closed',
#   'Case ID': 27},
#  {'variant': 'Take in charge ticket,Wait,Resolve ticket,Closed',
#   'Case ID': 21},
#  {'variant': 'Assign seriousness,Take in charge ticket,Wait,Wait,Take in charge ticket,Resolve ticket,Closed',
#   'Case ID': 21},
#  {'variant': 'Assign seriousness,Assign seriousness,Take in charge ticket,Wait,Resolve ticket,Closed',
#   'Case ID': 21},
#  {'variant': 'Assign seriousness,Take in charge ticket,Create SW anomaly,Resolve ticket,Closed',
#   'Case ID': 20},
#  {'variant': 'Assign seriousness,Take in charge ticket,Resolve ticket,Take in charge ticket,Wait,Take in charge ticket,Resolve ticket,Closed',
#   'Case ID': 19},
#  {'variant': 'Assign seriousness,Assign seriousness,Resolve ticket,Closed',
#   'Case ID': 18},
#  {'variant': 'Assign seriousness,Take in charge ticket,Wait,Take in charge ticket,Wait,Take in charge ticket,Resolve ticket,Closed',
#   'Case ID': 17},
#  {'variant': 'Assign seriousness,Wait,Take in charge ticket,Resolve ticket,Closed',
#   'Case ID': 15},
#  {'variant': 'Assign seriousness,Assign seriousness,Assign seriousness,Take in charge ticket,Resolve ticket,Closed',
#   'Case ID': 15},
#  {'variant': 'Assign seriousness,Wait,Resolve ticket,Closed', 'Case ID': 14},
#  {'variant': 'Assign seriousness,Take in charge ticket,Wait,Resolve ticket,Resolve ticket,Closed',
#   'Case ID': 11},
#  {'variant': 'Assign seriousness,Take in charge ticket,Wait,Take in charge ticket,Resolve ticket,Take in charge ticket,Resolve ticket,Closed',
#   'Case ID': 10},
#  {'variant': 'Assign seriousness,Take in charge ticket,Take in charge ticket,Wait,Resolve ticket,Closed',
#   'Case ID': 9},
#  {'variant': 'Insert ticket,Assign seriousness,Assign seriousness,Take in charge ticket,Resolve ticket,Closed',
#   'Case ID': 8},
#  {'variant': 'Assign seriousness,Take in charge ticket,Take in charge ticket,Wait,Take in charge ticket,Resolve ticket,Closed',
#   'Case ID': 8},
#  {'variant': 'Assign seriousness,Assign seriousness,Take in charge ticket,Resolve ticket,Resolve ticket,Closed',
#   'Case ID': 8},
#  {'variant': 'Assign seriousness,Wait,Take in charge ticket,Wait,Take in charge ticket,Resolve ticket,Closed',
#   'Case ID': 7},
#  {'variant': 'Assign seriousness,Take in charge ticket,Take in charge ticket,Take in charge ticket,Resolve ticket,Closed',
#   'Case ID': 7},
#  {'variant': 'Assign seriousness,Take in charge ticket,Resolve ticket,Closed,Closed',
#   'Case ID': 7},
#  {'variant': 'Insert ticket,Assign seriousness,Take in charge ticket,Wait,Take in charge ticket,Resolve ticket,Closed',
#   'Case ID': 6},
#  {'variant': 'Assign seriousness,Wait,Wait,Resolve ticket,Closed',
#   'Case ID': 6},
#  {'variant': 'Assign seriousness,Take in charge ticket,Require upgrade,Wait,Resolve ticket,Closed',
#   'Case ID': 6},
#  {'variant': 'Insert ticket,Assign seriousness,Assign seriousness,Take in charge ticket,Wait,Take in charge ticket,Resolve ticket,Closed',
#   'Case ID': 5},
#  {'variant': 'Assign seriousness,Take in charge ticket,Wait,Take in charge ticket,Resolve ticket,Resolve ticket,Closed',
#   'Case ID': 5},
#  {'variant': 'Assign seriousness,Require upgrade,Resolve ticket,Closed',
#   'Case ID': 5},
#  {'variant': 'Assign seriousness,Assign seriousness,Assign seriousness,Take in charge ticket,Wait,Resolve ticket,Closed',
#   'Case ID': 5},
#  {'variant': 'Take in charge ticket,Resolve ticket,Resolve ticket,Closed',
#   'Case ID': 4},
#  {'variant': 'Insert ticket,Assign seriousness,Take in charge ticket,Wait,Resolve ticket,Closed',
#   'Case ID': 4},
#  {'variant': 'Assign seriousness,Wait,Take in charge ticket,Resolve ticket,Resolve ticket,Closed',
#   'Case ID': 4},
#  {'variant': 'Assign seriousness,Wait,Resolve ticket,Resolve ticket,Closed',
#   'Case ID': 4},
#  {'variant': 'Assign seriousness,Take in charge ticket,Wait,Wait,Resolve ticket,Resolve ticket,Closed',
#   'Case ID': 4},
#  {'variant': 'Assign seriousness,Take in charge ticket,Wait,Resolve ticket,Take in charge ticket,Wait,Resolve ticket,Closed',
#   'Case ID': 4},
#  {'variant': 'Assign seriousness,Take in charge ticket,Resolve ticket,Take in charge ticket,Wait,Resolve ticket,Closed',
#   'Case ID': 4},
#  {'variant': 'Assign seriousness,Take in charge ticket,Require upgrade,Resolve ticket,Resolve ticket,Closed',
#   'Case ID': 4},
#  {'variant': 'Assign seriousness,Take in charge ticket,Require upgrade,Require upgrade,Resolve ticket,Closed',
#   'Case ID': 4},
#  {'variant': 'Assign seriousness,Take in charge ticket,Create SW anomaly,Require upgrade,Resolve ticket,Closed',
#   'Case ID': 4},
#  {'variant': 'Assign seriousness,Assign seriousness,Assign seriousness,Take in charge ticket,Wait,Take in charge ticket,Resolve ticket,Closed',
#   'Case ID': 4},
#  {'variant': 'Take in charge ticket,Wait,Take in charge ticket,Wait,Resolve ticket,Closed',
#   'Case ID': 3},
#  {'variant': 'Insert ticket,Wait,Wait', 'Case ID': 3},
#  {'variant': 'Insert ticket,Take in charge ticket,Resolve ticket,Closed',
#   'Case ID': 3},
#  {'variant': 'Insert ticket,Assign seriousness,Take in charge ticket,Resolve ticket,Take in charge ticket,Wait,Take in charge ticket,Resolve ticket,Closed',
#   'Case ID': 3},
#  {'variant': 'Insert ticket,Assign seriousness,Assign seriousness,Assign seriousness,Take in charge ticket,Resolve ticket,Closed',
#   'Case ID': 3},
#  {'variant': 'Assign seriousness,Wait,Take in charge ticket,Wait,Resolve ticket,Closed',
#   'Case ID': 3},
#  {'variant': 'Assign seriousness,Take in charge ticket,Wait,Wait,Wait,Resolve ticket,Closed',
#   'Case ID': 3},
#  {'variant': 'Assign seriousness,Take in charge ticket,Wait,Take in charge ticket,Resolve ticket,Closed,Closed',
#   'Case ID': 3},
#  {'variant': 'Assign seriousness,Take in charge ticket,Require upgrade,Take in charge ticket,Resolve ticket,Closed',
#   'Case ID': 3},
#  {'variant': 'Assign seriousness,Take in charge ticket,Create SW anomaly,Require upgrade,Require upgrade,Resolve ticket',
#   'Case ID': 3},
#  {'variant': 'Assign seriousness,Assign seriousness,Take in charge ticket,Wait,Wait,Take in charge ticket,Resolve ticket,Closed',
#   'Case ID': 3},
#  {'variant': 'Assign seriousness,Assign seriousness,Take in charge ticket,Wait,Take in charge ticket,Wait,Resolve ticket,Closed',
#   'Case ID': 3},
#  {'variant': 'Assign seriousness,Assign seriousness,Take in charge ticket,Take in charge ticket,Resolve ticket,Closed',
#   'Case ID': 3},
#  {'variant': 'Assign seriousness,Assign seriousness,Assign seriousness,Resolve ticket,Closed',
#   'Case ID': 3},
#  {'variant': 'Take in charge ticket,Wait,Take in charge ticket,Resolve ticket,Resolve ticket,Closed',
#   'Case ID': 2},
#  {'variant': 'Insert ticket,Assign seriousness,Take in charge ticket,Wait,Take in charge ticket,Wait,Take in charge ticket,Resolve ticket,Closed',
#   'Case ID': 2},
#  {'variant': 'Assign seriousness,Take in charge ticket,Wait,Wait,Wait,Wait,Resolve ticket,Closed',
#   'Case ID': 2},
#  {'variant': 'Assign seriousness,Take in charge ticket,Wait,Take in charge ticket,Wait,Take in charge ticket,Wait,Take in charge ticket,Resolve ticket,Closed',
#   'Case ID': 2},
#  {'variant': 'Assign seriousness,Take in charge ticket,Wait,Take in charge ticket,Wait,Resolve ticket,Resolve ticket,Closed',
#   'Case ID': 2},
#  {'variant': 'Assign seriousness,Take in charge ticket,Wait,Take in charge ticket,Take in charge ticket,Resolve ticket,Closed',
#   'Case ID': 2},
#  {'variant': 'Assign seriousness,Take in charge ticket,Wait,Take in charge ticket,Resolve ticket,Take in charge ticket,Wait,Take in charge ticket,Resolve ticket,Closed',
#   'Case ID': 2},
#  {'variant': 'Assign seriousness,Take in charge ticket,Wait,Resolve ticket,Take in charge ticket,Resolve ticket,Closed',
#   'Case ID': 2},
#  {'variant': 'Assign seriousness,Take in charge ticket,Wait,Require upgrade,Resolve ticket,Closed',
#   'Case ID': 2},
#  {'variant': 'Assign seriousness,Take in charge ticket,Take in charge ticket,Wait,Wait,Take in charge ticket,Resolve ticket,Closed',
#   'Case ID': 2},
#  {'variant': 'Assign seriousness,Take in charge ticket,Take in charge ticket,Take in charge ticket,Wait,Take in charge ticket,Resolve ticket,Closed',
#   'Case ID': 2},
#  {'variant': 'Assign seriousness,Take in charge ticket,Schedule intervention,Resolve ticket,Closed',
#   'Case ID': 2},
#  {'variant': 'Assign seriousness,Take in charge ticket,Resolve ticket,Take in charge ticket,Resolve ticket,Resolve ticket,Closed',
#   'Case ID': 2},
#  {'variant': 'Assign seriousness,Take in charge ticket,Resolve ticket,Take in charge ticket,Create SW anomaly,Resolve ticket,Closed',
#   'Case ID': 2},
#  {'variant': 'Assign seriousness,Take in charge ticket,Resolve ticket',
#   'Case ID': 2},
#  {'variant': 'Assign seriousness,Take in charge ticket,Require upgrade,Resolve ticket',
#   'Case ID': 2},
#  {'variant': 'Assign seriousness,Take in charge ticket,Create SW anomaly,Take in charge ticket,Wait,Resolve ticket,Closed',
#   'Case ID': 2},
#  {'variant': 'Assign seriousness,Resolve ticket,Take in charge ticket,Resolve ticket,Closed',
#   'Case ID': 2},
#  {'variant': 'Assign seriousness,Require upgrade,Resolve ticket,Resolve ticket,Closed',
#   'Case ID': 2},
#  {'variant': 'Assign seriousness,Create SW anomaly,Create SW anomaly,Resolve SW anomaly,Resolve SW anomaly,Require upgrade,Resolve ticket,Closed',
#   'Case ID': 2},
#  {'variant': 'Assign seriousness,Assign seriousness,Wait,Take in charge ticket,Resolve ticket,Closed',
#   'Case ID': 2},
#  {'variant': 'Assign seriousness,Assign seriousness,Take in charge ticket,Wait,Wait,Resolve ticket,Closed',
#   'Case ID': 2},
#  {'variant': 'Assign seriousness,Assign seriousness,Take in charge ticket,Wait,Take in charge ticket,Wait,Take in charge ticket,Resolve ticket,Closed',
#   'Case ID': 2},
#  {'variant': 'Assign seriousness,Assign seriousness,Take in charge ticket,Resolve ticket,Take in charge ticket,Resolve ticket,Closed',
#   'Case ID': 2},
#  {'variant': 'Assign seriousness,Assign seriousness,Assign seriousness,Take in charge ticket,Wait,Take in charge ticket,Wait,Take in charge ticket,Resolve ticket,Closed',
#   'Case ID': 2},
#  {'variant': 'Wait,Resolve ticket,Closed', 'Case ID': 1},
#  {'variant': 'Take in charge ticket,Wait,Wait,Resolve ticket,Closed',
#   'Case ID': 1},
#  {'variant': 'Take in charge ticket,Wait,Resolve ticket,Take in charge ticket,Wait,Resolve ticket,Closed',
#   'Case ID': 1},
#  {'variant': 'Take in charge ticket,Take in charge ticket,Take in charge ticket,Resolve ticket,Closed',
#   'Case ID': 1},
#  {'variant': 'Take in charge ticket,Take in charge ticket,Resolve ticket,Closed',
#   'Case ID': 1},
#  {'variant': 'Take in charge ticket,Resolve ticket,Take in charge ticket,Wait,Take in charge ticket,Wait,Resolve ticket,Closed',
#   'Case ID': 1},
#  {'variant': 'Take in charge ticket,Resolve ticket,Take in charge ticket,Wait,Take in charge ticket,Resolve ticket,Closed',
#   'Case ID': 1},
#  {'variant': 'Take in charge ticket,Resolve ticket,Resolve ticket,Resolve ticket,Closed',
#   'Case ID': 1},
#  {'variant': 'Resolve ticket,Take in charge ticket,Resolve ticket,Closed',
#   'Case ID': 1},
#  {'variant': 'Resolve ticket,Closed', 'Case ID': 1},
#  {'variant': 'Insert ticket,Wait,Wait,Wait,Wait', 'Case ID': 1},
#  {'variant': 'Insert ticket,Assign seriousness,Take in charge ticket,Wait,Wait,Take in charge ticket,Resolve ticket,Closed',
#   'Case ID': 1},
#  {'variant': 'Insert ticket,Assign seriousness,Take in charge ticket,Resolve ticket,Take in charge ticket,Resolve ticket,Resolve ticket,Closed',
#   'Case ID': 1},
#  {'variant': 'Insert ticket,Assign seriousness,Take in charge ticket,Resolve ticket,Take in charge ticket,Resolve ticket,Closed',
#   'Case ID': 1},
#  {'variant': 'Insert ticket,Assign seriousness,Take in charge ticket,Resolve ticket,Resolve ticket,Closed',
#   'Case ID': 1},
#  {'variant': 'Insert ticket,Assign seriousness,Take in charge ticket,Resolve ticket,Closed,Closed',
#   'Case ID': 1},
#  {'variant': 'Insert ticket,Assign seriousness,Take in charge ticket,Create SW anomaly,Resolve ticket,Closed',
#   'Case ID': 1},
#  {'variant': 'Insert ticket,Assign seriousness,Take in charge ticket,Assign seriousness,Assign seriousness,Wait,Take in charge ticket,Resolve ticket,Closed',
#   'Case ID': 1},
#  {'variant': 'Insert ticket,Assign seriousness,Resolve ticket,Closed',
#   'Case ID': 1},
#  {'variant': 'Insert ticket,Assign seriousness,Assign seriousness,Wait,Take in charge ticket,Resolve ticket,Take in charge ticket,Resolve ticket,Closed',
#   'Case ID': 1},
#  {'variant': 'Insert ticket,Assign seriousness,Assign seriousness,Take in charge ticket,Wait,Resolve ticket,Closed',
#   'Case ID': 1},
#  {'variant': 'Insert ticket,Assign seriousness,Assign seriousness,Assign seriousness,Assign seriousness,Take in charge ticket,Resolve ticket,Closed',
#   'Case ID': 1},
#  {'variant': 'Create SW anomaly,Resolve SW anomaly,Resolve ticket,Closed',
#   'Case ID': 1},
#  {'variant': 'Assign seriousness,Wait,Wait,Take in charge ticket,Resolve ticket,Resolve ticket,Closed',
#   'Case ID': 1},
#  {'variant': 'Assign seriousness,Wait,Wait,Take in charge ticket,Resolve ticket,Closed',
#   'Case ID': 1},
#  {'variant': 'Assign seriousness,Wait,Wait,Resolve ticket,Take in charge ticket,Resolve ticket,Resolve ticket,Closed',
#   'Case ID': 1},
#  {'variant': 'Assign seriousness,Wait,Take in charge ticket,Wait,Take in charge ticket,Resolve ticket,Take in charge ticket,Wait,Take in charge ticket,Resolve ticket,Take in charge ticket,Wait,Take in charge ticket,Resolve ticket,Closed',
#   'Case ID': 1},
#  {'variant': 'Assign seriousness,Wait,Take in charge ticket,Wait,Take in charge ticket,Resolve ticket,Take in charge ticket,Wait,Take in charge ticket,Resolve ticket,Closed',
#   'Case ID': 1},
#  {'variant': 'Assign seriousness,Wait,Take in charge ticket,Resolve ticket,Take in charge ticket,Wait,Take in charge ticket,Resolve ticket,Closed',
#   'Case ID': 1},
#  {'variant': 'Assign seriousness,Wait,Assign seriousness,Take in charge ticket,Wait,Wait,Take in charge ticket,Resolve ticket,Closed',
#   'Case ID': 1},
#  {'variant': 'Assign seriousness,Wait,Assign seriousness,Assign seriousness,Take in charge ticket,Resolve ticket,Closed',
#   'Case ID': 1},
#  {'variant': 'Assign seriousness,Take in charge ticket,Wait,Wait,Wait,Wait,Wait',
#   'Case ID': 1},
#  {'variant': 'Assign seriousness,Take in charge ticket,Wait,Wait,Wait,Take in charge ticket,Resolve ticket,Closed',
#   'Case ID': 1},
#  {'variant': 'Assign seriousness,Take in charge ticket,Wait,Wait,Wait,Resolve ticket,Resolve ticket,Closed',
#   'Case ID': 1},
#  {'variant': 'Assign seriousness,Take in charge ticket,Wait,Wait,Take in charge ticket,Wait,Wait,Take in charge ticket,Take in charge ticket,Take in charge ticket,Resolve ticket,Closed',
#   'Case ID': 1},
#  {'variant': 'Assign seriousness,Take in charge ticket,Wait,Wait,Take in charge ticket,Wait,Take in charge ticket,Resolve ticket,Closed',
#   'Case ID': 1},
#  {'variant': 'Assign seriousness,Take in charge ticket,Wait,Wait,Take in charge ticket,Wait,Take in charge ticket,Create SW anomaly,Resolve ticket,Closed',
#   'Case ID': 1},
#  {'variant': 'Assign seriousness,Take in charge ticket,Wait,Wait,Take in charge ticket,Wait,Resolve ticket,Closed',
#   'Case ID': 1},
#  {'variant': 'Assign seriousness,Take in charge ticket,Wait,Wait,Take in charge ticket,Resolve ticket,Resolve ticket,Resolve ticket,Closed',
#   'Case ID': 1},
#  {'variant': 'Assign seriousness,Take in charge ticket,Wait,Wait,Resolve ticket,Take in charge ticket,Wait,Resolve ticket,Closed',
#   'Case ID': 1},
#  {'variant': 'Assign seriousness,Take in charge ticket,Wait,Wait,Resolve ticket,Take in charge ticket,Resolve ticket,Closed',
#   'Case ID': 1},
#  {'variant': 'Assign seriousness,Take in charge ticket,Wait,Wait,Create SW anomaly,Resolve ticket,Closed',
#   'Case ID': 1},
#  {'variant': 'Assign seriousness,Take in charge ticket,Wait,Take in charge ticket,Wait,Take in charge ticket,Wait,Take in charge ticket,Wait,Take in charge ticket,Resolve ticket,Closed',
#   'Case ID': 1},
#  {'variant': 'Assign seriousness,Take in charge ticket,Wait,Take in charge ticket,Wait,Take in charge ticket,Wait,Take in charge ticket,Resolve ticket,Take in charge ticket,Wait,Take in charge ticket,Resolve ticket,Closed',
#   'Case ID': 1},
#  {'variant': 'Assign seriousness,Take in charge ticket,Wait,Take in charge ticket,Wait,Take in charge ticket,Resolve ticket,Take in charge ticket,Wait,Take in charge ticket,Resolve ticket,Closed',
#   'Case ID': 1},
#  {'variant': 'Assign seriousness,Take in charge ticket,Wait,Take in charge ticket,Wait,Take in charge ticket,Resolve ticket,Take in charge ticket,Resolve ticket,Closed',
#   'Case ID': 1},
#  {'variant': 'Assign seriousness,Take in charge ticket,Wait,Take in charge ticket,Wait',
#   'Case ID': 1},
#  {'variant': 'Assign seriousness,Take in charge ticket,Wait,Take in charge ticket,Take in charge ticket,Wait,Take in charge ticket,Wait,Take in charge ticket,Resolve ticket,Closed',
#   'Case ID': 1},
#  {'variant': 'Assign seriousness,Take in charge ticket,Wait,Take in charge ticket,Resolve ticket,Take in charge ticket,Wait,Take in charge ticket,Create SW anomaly,Resolve ticket,Take in charge ticket,Resolve ticket,Closed',
#   'Case ID': 1},
#  {'variant': 'Assign seriousness,Take in charge ticket,Wait,Take in charge ticket,Resolve ticket',
#   'Case ID': 1},
#  {'variant': 'Assign seriousness,Take in charge ticket,Wait,Take in charge ticket,Require upgrade,Resolve ticket,Closed',
#   'Case ID': 1},
#  {'variant': 'Assign seriousness,Take in charge ticket,Wait,Take in charge ticket,Require upgrade,Resolve ticket',
#   'Case ID': 1},
#  {'variant': 'Assign seriousness,Take in charge ticket,Wait,Take in charge ticket,Create SW anomaly,Resolve ticket,Take in charge ticket,Resolve ticket,Closed',
#   'Case ID': 1},
#  {'variant': 'Assign seriousness,Take in charge ticket,Wait,Take in charge ticket,Create SW anomaly,Resolve ticket,RESOLVED,INVALID,Closed,VERIFIED',
#   'Case ID': 1},
#  {'variant': 'Assign seriousness,Take in charge ticket,Wait,Resolve ticket,Wait,Resolve ticket,Closed',
#   'Case ID': 1},
#  {'variant': 'Assign seriousness,Take in charge ticket,Wait,Resolve ticket,Take in charge ticket,Take in charge ticket,Resolve ticket,Resolve ticket,Closed',
#   'Case ID': 1},
#  {'variant': 'Assign seriousness,Take in charge ticket,Wait,Require upgrade,Wait,Resolve ticket,Resolve ticket,Closed',
#   'Case ID': 1},
#  {'variant': 'Assign seriousness,Take in charge ticket,Wait,Require upgrade,Wait,Resolve ticket,Closed',
#   'Case ID': 1},
#  {'variant': 'Assign seriousness,Take in charge ticket,Wait,Require upgrade,Resolve ticket,Resolve ticket,Closed',
#   'Case ID': 1},
#  {'variant': 'Assign seriousness,Take in charge ticket,Wait,Require upgrade,Require upgrade,Resolve ticket,Closed',
#   'Case ID': 1},
#  {'variant': 'Assign seriousness,Take in charge ticket,Wait,Require upgrade',
#   'Case ID': 1},
#  {'variant': 'Assign seriousness,Take in charge ticket,Wait,Create SW anomaly,Require upgrade,Resolve ticket,Closed',
#   'Case ID': 1},
#  {'variant': 'Assign seriousness,Take in charge ticket,Wait', 'Case ID': 1},
#  {'variant': 'Assign seriousness,Take in charge ticket,Take in charge ticket,Wait,Wait,Resolve ticket,Closed',
#   'Case ID': 1},
#  {'variant': 'Assign seriousness,Take in charge ticket,Take in charge ticket,Wait,Take in charge ticket,Resolve ticket,Take in charge ticket,Wait,Take in charge ticket,Resolve ticket,Closed',
#   'Case ID': 1},
#  {'variant': 'Assign seriousness,Take in charge ticket,Take in charge ticket,Take in charge ticket,Wait,Wait,Take in charge ticket,Resolve ticket,Closed',
#   'Case ID': 1},
#  {'variant': 'Assign seriousness,Take in charge ticket,Take in charge ticket,Take in charge ticket,Resolve ticket,Take in charge ticket,Resolve ticket,Take in charge ticket,Take in charge ticket,Resolve ticket,Closed',
#   'Case ID': 1},
#  {'variant': 'Assign seriousness,Take in charge ticket,Take in charge ticket,Schedule intervention,Resolve ticket,Closed',
#   'Case ID': 1},
#  {'variant': 'Assign seriousness,Take in charge ticket,Take in charge ticket,Resolve ticket,Take in charge ticket,Resolve ticket,Closed',
#   'Case ID': 1},
#  {'variant': 'Assign seriousness,Take in charge ticket,Take in charge ticket,Require upgrade,Resolve ticket,Closed',
#   'Case ID': 1},
#  {'variant': 'Assign seriousness,Take in charge ticket,Take in charge ticket,Create SW anomaly,Resolve ticket,Closed',
#   'Case ID': 1},
#  {'variant': 'Assign seriousness,Take in charge ticket,Schedule intervention,Take in charge ticket,Wait,Take in charge ticket,Resolve ticket,Closed',
#   'Case ID': 1},
#  {'variant': 'Assign seriousness,Take in charge ticket,Resolve ticket,Wait,Resolve ticket,Closed',
#   'Case ID': 1},
#  {'variant': 'Assign seriousness,Take in charge ticket,Resolve ticket,Take in charge ticket,Wait,Take in charge ticket,Wait,Take in charge ticket,Wait,Resolve ticket,Closed',
#   'Case ID': 1},
#  {'variant': 'Assign seriousness,Take in charge ticket,Resolve ticket,Take in charge ticket,Take in charge ticket,Resolve ticket,Closed',
#   'Case ID': 1},
#  {'variant': 'Assign seriousness,Take in charge ticket,Resolve ticket,Take in charge ticket,Resolve ticket,Take in charge ticket,Wait,Take in charge ticket,Resolve ticket,Closed',
#   'Case ID': 1},
#  {'variant': 'Assign seriousness,Take in charge ticket,Resolve ticket,Take in charge ticket,Resolve ticket,Take in charge ticket,Create SW anomaly,Resolve ticket,Closed',
#   'Case ID': 1},
#  {'variant': 'Assign seriousness,Take in charge ticket,Resolve ticket,Take in charge ticket,Create SW anomaly,Resolve ticket,Take in charge ticket,Create SW anomaly,Resolve ticket,Closed',
#   'Case ID': 1},
#  {'variant': 'Assign seriousness,Take in charge ticket,Resolve ticket,Resolve ticket,Take in charge ticket,Wait,Take in charge ticket,Resolve ticket,Closed',
#   'Case ID': 1},
#  {'variant': 'Assign seriousness,Take in charge ticket,Resolve ticket,Resolve ticket,Take in charge ticket,Wait,Resolve ticket,Closed',
#   'Case ID': 1},
#  {'variant': 'Assign seriousness,Take in charge ticket,Resolve ticket,Resolve ticket,Take in charge ticket,Resolve ticket,Closed',
#   'Case ID': 1},
#  {'variant': 'Assign seriousness,Take in charge ticket,Resolve ticket,Resolve ticket,Resolve ticket,Take in charge ticket,Resolve ticket,Closed',
#   'Case ID': 1},
#  {'variant': 'Assign seriousness,Take in charge ticket,Resolve ticket,Resolve ticket,Closed,Closed',
#   'Case ID': 1},
#  {'variant': 'Assign seriousness,Take in charge ticket,Resolve ticket,Assign seriousness,Take in charge ticket,Resolve ticket,Closed',
#   'Case ID': 1},
#  {'variant': 'Assign seriousness,Take in charge ticket,Resolve SW anomaly,Resolve ticket,Closed',
#   'Case ID': 1},
#  {'variant': 'Assign seriousness,Take in charge ticket,Require upgrade,Take in charge ticket,Wait,Resolve ticket,Closed',
#   'Case ID': 1},
#  {'variant': 'Assign seriousness,Take in charge ticket,Require upgrade,Require upgrade,Take in charge ticket,Resolve ticket,Resolve ticket,Closed',
#   'Case ID': 1},
#  {'variant': 'Assign seriousness,Take in charge ticket,Require upgrade,Require upgrade,Resolve ticket,Resolve ticket,Closed',
#   'Case ID': 1},
#  {'variant': 'Assign seriousness,Take in charge ticket,Require upgrade,Require upgrade,Require upgrade,Resolve ticket,Closed',
#   'Case ID': 1},
#  {'variant': 'Assign seriousness,Take in charge ticket,Require upgrade,Require upgrade,Create SW anomaly,Require upgrade',
#   'Case ID': 1},
#  {'variant': 'Assign seriousness,Take in charge ticket,Require upgrade,Create SW anomaly,Resolve ticket,RESOLVED,INVALID,VERIFIED,Closed',
#   'Case ID': 1},
#  {'variant': 'Assign seriousness,Take in charge ticket,Create SW anomaly,Resolve ticket,Take in charge ticket,Resolve ticket,Closed',
#   'Case ID': 1},
#  {'variant': 'Assign seriousness,Take in charge ticket,Create SW anomaly,Resolve ticket,Take in charge ticket,Create SW anomaly,Resolve ticket,Closed',
#   'Case ID': 1},
#  {'variant': 'Assign seriousness,Take in charge ticket,Create SW anomaly,Resolve SW anomaly,Resolve SW anomaly,Resolve ticket,Closed',
#   'Case ID': 1},
#  {'variant': 'Assign seriousness,Take in charge ticket,Create SW anomaly,Resolve SW anomaly,Resolve SW anomaly,Require upgrade',
#   'Case ID': 1},
#  {'variant': 'Assign seriousness,Take in charge ticket,Create SW anomaly,Create SW anomaly,Resolve ticket,Closed',
#   'Case ID': 1},
#  {'variant': 'Assign seriousness,Take in charge ticket,Create SW anomaly,Create SW anomaly,Resolve SW anomaly,Resolve SW anomaly,Require upgrade,Create SW anomaly,Resolve ticket',
#   'Case ID': 1},
#  {'variant': 'Assign seriousness,Resolve ticket,Wait,Wait,Resolve ticket,Closed',
#   'Case ID': 1},
#  {'variant': 'Assign seriousness,Resolve ticket,Take in charge ticket,Require upgrade,Resolve ticket,Closed',
#   'Case ID': 1},
#  {'variant': 'Assign seriousness,Resolve ticket,Resolve ticket,Take in charge ticket,Resolve ticket,Resolve ticket,Closed',
#   'Case ID': 1},
#  {'variant': 'Assign seriousness,Resolve ticket,Resolve ticket,Take in charge ticket,Resolve ticket,Closed',
#   'Case ID': 1},
#  {'variant': 'Assign seriousness,Resolve ticket,Resolve ticket,Resolve ticket,Closed',
#   'Case ID': 1},
#  {'variant': 'Assign seriousness,Resolve ticket,Closed,Take in charge ticket',
#   'Case ID': 1},
#  {'variant': 'Assign seriousness,Require upgrade,Require upgrade,Resolve ticket,Closed',
#   'Case ID': 1},
#  {'variant': 'Assign seriousness,Create SW anomaly,Take in charge ticket,Create SW anomaly,Require upgrade,VERIFIED,DUPLICATE,Resolve ticket,Closed',
#   'Case ID': 1},
#  {'variant': 'Assign seriousness,Create SW anomaly,Require upgrade,Resolve ticket,Closed',
#   'Case ID': 1},
#  {'variant': 'Assign seriousness,Assign seriousness,Wait,Wait,Resolve ticket,Closed',
#   'Case ID': 1},
#  {'variant': 'Assign seriousness,Assign seriousness,Wait,Take in charge ticket,Wait,Take in charge ticket,Resolve ticket,Closed',
#   'Case ID': 1},
#  {'variant': 'Assign seriousness,Assign seriousness,Take in charge ticket,Wait,Wait',
#   'Case ID': 1},
#  {'variant': 'Assign seriousness,Assign seriousness,Take in charge ticket,Wait,Take in charge ticket,Resolve ticket,Take in charge ticket,Wait,Take in charge ticket,Resolve ticket,Closed',
#   'Case ID': 1},
#  {'variant': 'Assign seriousness,Assign seriousness,Take in charge ticket,Wait,Take in charge ticket,Resolve ticket,Take in charge ticket,Take in charge ticket,Take in charge ticket,Resolve ticket,Closed',
#   'Case ID': 1},
#  {'variant': 'Assign seriousness,Assign seriousness,Take in charge ticket,Wait,Take in charge ticket,Require upgrade,Require upgrade,Resolve ticket,Closed',
#   'Case ID': 1},
#  {'variant': 'Assign seriousness,Assign seriousness,Take in charge ticket,Wait,Take in charge ticket,Create SW anomaly,Resolve ticket,Closed',
#   'Case ID': 1},
#  {'variant': 'Assign seriousness,Assign seriousness,Take in charge ticket,Wait,Resolve ticket,Take in charge ticket,Resolve ticket,Closed',
#   'Case ID': 1},
#  {'variant': 'Assign seriousness,Assign seriousness,Take in charge ticket,Schedule intervention,Resolve ticket,Closed',
#   'Case ID': 1},
#  {'variant': 'Assign seriousness,Assign seriousness,Take in charge ticket,Resolve ticket,Take in charge ticket,Wait,Take in charge ticket,Resolve ticket,Take in charge ticket,Wait,Take in charge ticket,Resolve ticket,Closed',
#   'Case ID': 1},
#  {'variant': 'Assign seriousness,Assign seriousness,Take in charge ticket,Resolve ticket,Take in charge ticket,Wait,Take in charge ticket,Resolve ticket,Closed',
#   'Case ID': 1},
#  {'variant': 'Assign seriousness,Assign seriousness,Take in charge ticket,Resolve ticket,Take in charge ticket,Resolve ticket,Resolve ticket,Resolve ticket,Require upgrade,Take in charge ticket,Wait,Wait,Resolve ticket,Closed',
#   'Case ID': 1},
#  {'variant': 'Assign seriousness,Assign seriousness,Take in charge ticket,Resolve ticket,Take in charge ticket,Resolve ticket,Closed,Closed',
#   'Case ID': 1},
#  {'variant': 'Assign seriousness,Assign seriousness,Take in charge ticket,Resolve ticket,Resolve ticket,Resolve ticket,Closed',
#   'Case ID': 1},
#  {'variant': 'Assign seriousness,Assign seriousness,Take in charge ticket,Resolve ticket,Closed,Take in charge ticket,Resolve ticket,Closed',
#   'Case ID': 1},
#  {'variant': 'Assign seriousness,Assign seriousness,Take in charge ticket,Resolve ticket,Closed,Closed',
#   'Case ID': 1},
#  {'variant': 'Assign seriousness,Assign seriousness,Take in charge ticket,Require upgrade,Resolve ticket,Closed',
#   'Case ID': 1},
#  {'variant': 'Assign seriousness,Assign seriousness,Take in charge ticket,Require upgrade,Require upgrade,Resolve ticket,Closed',
#   'Case ID': 1},
#  {'variant': 'Assign seriousness,Assign seriousness,Take in charge ticket,Create SW anomaly,Resolve ticket,Closed',
#   'Case ID': 1},
#  {'variant': 'Assign seriousness,Assign seriousness,Take in charge ticket,Create SW anomaly,Resolve SW anomaly,Resolve ticket,Closed',
#   'Case ID': 1},
#  {'variant': 'Assign seriousness,Assign seriousness,Assign seriousness,Wait,Take in charge ticket,Resolve ticket,Closed',
#   'Case ID': 1},
#  {'variant': 'Assign seriousness,Assign seriousness,Assign seriousness,Wait,Resolve ticket,Closed',
#   'Case ID': 1},
#  {'variant': 'Assign seriousness,Assign seriousness,Assign seriousness,Take in charge ticket,Resolve ticket,Take in charge ticket,Wait,Take in charge ticket,Resolve ticket,Closed',
#   'Case ID': 1},
#  {'variant': 'Assign seriousness,Assign seriousness,Assign seriousness,Take in charge ticket,Resolve ticket,Take in charge ticket,Create SW anomaly,Resolve ticket,Take in charge ticket,Create SW anomaly,Resolve ticket,Closed',
#   'Case ID': 1},
#  {'variant': 'Assign seriousness,Assign seriousness,Assign seriousness,Take in charge ticket,Resolve ticket,Resolve ticket,Closed',
#   'Case ID': 1},
#  {'variant': 'Assign seriousness,Assign seriousness,Assign seriousness,Resolve ticket,Resolve ticket,Closed',
#   'Case ID': 1},
#  {'variant': 'Assign seriousness,Assign seriousness,Assign seriousness,Assign seriousness,Take in charge ticket,Wait,Take in charge ticket,Resolve ticket,Closed',
#   'Case ID': 1},
#  {'variant': 'Assign seriousness,Assign seriousness,Assign seriousness,Assign seriousness,Take in charge ticket,Resolve ticket,Closed',
#   'Case ID': 1},
#  {'variant': 'Assign seriousness,Assign seriousness,Assign seriousness,Assign seriousness,Resolve ticket,Take in charge ticket,Resolve ticket,Closed',
#   'Case ID': 1}]

# %%
variants = case_statistics.get_variants_df(log_csv,
                                          parameters={constants.PARAMETER_CONSTANT_CASEID_KEY: "Case ID",
                                                      constants.PARAMETER_CONSTANT_ACTIVITY_KEY: "Activity"})
count1 = df['Case ID'].count()
print('count cases: ' + str(count1))
print(variants)
# Out:
# count cases: 21342
#                                                      variant
# Case ID
# Case 1     Assign seriousness,Take in charge ticket,Take ...
# Case 10    Assign seriousness,Take in charge ticket,Resol...
# Case 100   Assign seriousness,Take in charge ticket,Requi...
# Case 1000  Assign seriousness,Assign seriousness,Take in ...
# Case 1001  Assign seriousness,Take in charge ticket,Resol...
# ...                                                      ...
# Case 995   Assign seriousness,Take in charge ticket,Wait,...
# Case 996   Assign seriousness,Take in charge ticket,Resol...
# Case 997   Assign seriousness,Take in charge ticket,Resol...
# Case 998   Assign seriousness,Take in charge ticket,Wait,...
# Case 999   Assign seriousness,Take in charge ticket,Resol...
#
# [4579 rows x 1 columns]

# %%
log_csv = pd.read_csv('../eventlogs/ItalianHelpdeskFinal.csv', sep=',')
#log_csv.rename(columns={'clientID': 'case:clientID'}, inplace=True)
event_log = log_converter.apply(log_csv, parameters=param_keys, variant=log_converter.Variants.TO_EVENT_LOG)
event_log[0][3]
# Out:
# {'Case ID': 'Case 1', 'Activity': 'Resolve ticket', 'org:resource': 'Value 1', 'Complete Timestamp': '2012/10/25 11:54:26.000', 'seriousness': 'Value 1', 'customer': 'Value 1', 'product': 'Value 1', 'seriousness_2': 'Value 1', 'service_level': 'Value 2', 'service_type': 'Value 1', 'workgroup': 'Value 1'}

# %% [markdown]
# ## 2-Distribution Computation:

# %% [markdown]
# ## 3-Sorting the cases of each variant:
